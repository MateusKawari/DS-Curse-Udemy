# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusKawari/DS-Curse-Udemy/blob/main/PD_TREINAMENTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Treinando com a documentação Pandas, fazendo análises estudando a documentação.
# Análise de dataframe do Kaggle sobre Percepção dos Brasileiros em relação as queimadas de 2022.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Queimadas2022Percepção.csv')

# %%
df
# Out:
#      fator_ponderacao       sexo   faixa_idade estado municipio_condicao  \
# 0            0,565119   Feminino  35 a 44 anos     SP         Capital RM
# 1            0,973904  Masculino  45 a 59 anos     SP           Interior
# 2            1,025108  Masculino  25 a 34 anos     SP          Periferia
# 3            0,819887  Masculino  35 a 44 anos     SP           Interior
# 4            1,025108  Masculino  25 a 34 anos     SP           Interior
# ...               ...        ...           ...    ...                ...
# 2595         0,542138   Feminino  25 a 34 anos     PA           Interior
# 2596         0,691136  Masculino  60 anos ou +     AM           Interior
# 2597          0,30244  Masculino  35 a 44 anos     PA           Interior
# 2598         1,046172   Feminino  60 anos ou +     PA           Interior
# 2599          0,68159   Feminino  45 a 59 anos     PA          Periferia
#
#        regiao classe_economica alfabetizado  \
# 0     Sudeste                A          Sim
# ...

# %%
df["regiao"]
# Out:
# 0       Sudeste
# 1       Sudeste
# 2       Sudeste
# 3       Sudeste
# 4       Sudeste
#          ...
# 2595      Norte
# 2596      Norte
# 2597      Norte
# 2598      Norte
# 2599      Norte
# Name: regiao, Length: 2600, dtype: object

# %%
# Saber o valor máximo de idade de entrevista.
df['faixa_idade'].max()
# Out:
# '60 anos ou +'

# %%
# Ler as 10 primeiras linhas do meu dataframe
df.head(10)
# Out:
#   fator_ponderacao       sexo   faixa_idade estado municipio_condicao  \
# 0         0,565119   Feminino  35 a 44 anos     SP         Capital RM
# 1         0,973904  Masculino  45 a 59 anos     SP           Interior
# 2         1,025108  Masculino  25 a 34 anos     SP          Periferia
# 3         0,819887  Masculino  35 a 44 anos     SP           Interior
# 4         1,025108  Masculino  25 a 34 anos     SP           Interior
# 5         2,134075  Masculino  60 anos ou +     SP           Interior
# 6         1,570708  Masculino  35 a 44 anos     SP           Interior
# 7         3,239573  Masculino  60 anos ou +     SP           Interior
# 8         1,225606   Feminino  25 a 34 anos     SP           Interior
# 9          1,08464   Feminino  18 a 24 anos     SP           Interior
#
#     regiao classe_economica alfabetizado                       escolaridade  \
# 0  Sudeste                A          Sim                  Superior completo
# ...

# %%
# Ler os 10 últimos do meu dataframe
df.tail(10)
# Out:
#      fator_ponderacao       sexo   faixa_idade estado municipio_condicao  \
# 2590          0,91603  Masculino  45 a 59 anos     AL         Capital RM
# 2591         0,280859  Masculino  45 a 59 anos     PA           Interior
# 2592         0,436376  Masculino  25 a 34 anos     PA           Interior
# 2593         0,282291   Feminino  35 a 44 anos     PA         Capital RM
# 2594          0,90805  Masculino  25 a 34 anos     BA           Interior
# 2595         0,542138   Feminino  25 a 34 anos     PA           Interior
# 2596         0,691136  Masculino  60 anos ou +     AM           Interior
# 2597          0,30244  Masculino  35 a 44 anos     PA           Interior
# 2598         1,046172   Feminino  60 anos ou +     PA           Interior
# 2599          0,68159   Feminino  45 a 59 anos     PA          Periferia
#
#         regiao classe_economica alfabetizado  \
# 2590  Nordeste               C2          Sim
# 2591     Norte               B2          Sim
# ...
