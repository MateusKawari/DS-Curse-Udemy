# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusKawari/DS-Curse-Udemy/blob/main/FifaP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 14 - Realizando a leitura dos dados

# %%
import pandas as pd

# %%
dados_fifa = pd.read_csv('/content/fifa.csv')

# %%
dados_fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# Quando quero ver as primeiras linhas e colunas, assim como as últimas linhas e colunas.

# %%
# Usase as funções nomedoDado.head() para os primeiros e .tail() para os últimos

# %%
dados_fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Vendo os cinco primeiros, mas caso queira ver mais dados ou menos.
dados_fifa.head(15)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %%
# Vendo os últimos.
dados_fifa.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
dados_fifa.tail(10)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18197       18197  246167          D. Holland   18
# 18198       18198  242844          J. Livesey   18
# 18199       18199  244677        M. Baldisimo   18
# 18200       18200  231381            J. Young   18
# 18201       18201  243413            D. Walsh   18
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo          Nationality  \
# 18197  https://cdn.sofifa.org/players/4/19/246167.png  Republic of Ireland
# 18198  https://cdn.sofifa.org/players/4/19/242844.png              England
# 18199  https://cdn.sofifa.org/players/4/19/244677.png               Canada
# 18200  https://cdn.sofifa.org/players/4/19/231381.png             Scotland
# ...

# %%
# Quero saber quais são as colunas.
dados_fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# Saber quais são as rows(linhas)
dados_fifa.index
# O Step=1 diz que a linhas vão de 1 em 1.
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
# Manipulando os dados, escolhendo apenas uma coluna ou algumas delas.
dados_fifa['Name']
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
dados_fifa[['Name','Nationality', 'Wage']]
# Out:
#                      Name Nationality   Wage
# 0                L. Messi   Argentina  €565K
# 1       Cristiano Ronaldo    Portugal  €405K
# 2               Neymar Jr      Brazil  €290K
# 3                  De Gea       Spain  €260K
# 4            K. De Bruyne     Belgium  €355K
# ...                   ...         ...    ...
# 18202        J. Lundstram     England    €1K
# 18203  N. Christoffersson      Sweden    €1K
# 18204           B. Worman     England    €1K
# 18205      D. Walker-Rice     England    €1K
# 18206           G. Nugent     England    €1K
#
# [18207 rows x 3 columns]

# %%
# Manipulando ordem dos dados
dados_fifa[['Wage','Penalties','Name','Club']]
# Out:
#         Wage  Penalties                Name                 Club
# 0      €565K       75.0            L. Messi         FC Barcelona
# 1      €405K       85.0   Cristiano Ronaldo             Juventus
# 2      €290K       81.0           Neymar Jr  Paris Saint-Germain
# 3      €260K       40.0              De Gea    Manchester United
# 4      €355K       79.0        K. De Bruyne      Manchester City
# ...      ...        ...                 ...                  ...
# 18202    €1K       43.0        J. Lundstram      Crewe Alexandra
# 18203    €1K       43.0  N. Christoffersson       Trelleborgs FF
# 18204    €1K       55.0           B. Worman     Cambridge United
# 18205    €1K       50.0      D. Walker-Rice      Tranmere Rovers
# 18206    €1K       33.0           G. Nugent      Tranmere Rovers
#
# [18207 rows x 4 columns]

# %%
# Achando os dados conforme a lina
dados_fifa.iloc[45]
# Out:
# Unnamed: 0                                                    45
# ID                                                        195864
# Name                                                    P. Pogba
# Age                                                           25
# Photo             https://cdn.sofifa.org/players/4/19/195864.png
#                                        ...
# GKHandling                                                   6.0
# GKKicking                                                    2.0
# GKPositioning                                                4.0
# GKReflexes                                                   3.0
# Release Clause                                           €123.2M
# Name: 45, Length: 89, dtype: object

# %%
# Achando vários dados, conforme a ordem de numeração
dados_fifa.iloc[50:65]
# Out:
#     Unnamed: 0      ID             Name  Age  \
# 50          50  175943       D. Mertens   31
# 51          51  172871    J. Vertonghen   31
# 52          52  171877        M. Hamšík   30
# 53          53  168651       I. Rakitić   30
# 54          54  152729            Piqué   31
# 55          55  222492          L. Sané   22
# 56          56  218667   Bernardo Silva   23
# 57          57  210257          Ederson   24
# 58          58  208722          S. Mané   26
# 59          59  203376      V. van Dijk   26
# 60          60  202652      R. Sterling   23
# 61          61  201942  Roberto Firmino   26
# 62          62  201535        R. Varane   25
# 63          63  199556      M. Verratti   25
# 64          64  191043      Alex Sandro   27
#
#                                              Photo  Nationality  \
# 50  https://cdn.sofifa.org/players/4/19/175943.png      Belgium
# 51  https://cdn.sofifa.org/players/4/19/172871.png      Belgium
# ...

# %%
# Achando pelo número da coluna e pelo número da linha.
# Nesse caso, irá achar a celula específica da tabela.
dados_fifa.iloc[33,2]
# Out:
# 'P. Aubameyang'
